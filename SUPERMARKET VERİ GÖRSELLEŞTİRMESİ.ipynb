# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("supermarket.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.sample(15)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 720  418-05-0656      B   Mandalay        Normal  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 41   554-53-8700      C  Naypyitaw        Member    Male
# 923  887-42-0517      C  Naypyitaw        Normal  Female
# 868  631-34-1880      C  Naypyitaw        Member    Male
# 791  400-80-4065      C  Naypyitaw        Member    Male
# 253  290-68-2984      A     Yangon        Normal    Male
# 841  291-59-1384      B   Mandalay        Normal    Male
# 789  497-37-6538      A     Yangon        Normal    Male
# 494  437-53-3084      B   Mandalay        Normal    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 532  857-67-9057      B   Mandalay        Normal    Male
# 408  256-08-8343      A     Yangon        Normal  Female
# 983  148-41-7930      C  Naypyitaw        Normal    Male
# 176  175-54-2529      A     Yangon        Member    Male
#
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.sample(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 580  390-31-6381      C  Naypyitaw        Normal    Male
# 706  834-45-5519      B   Mandalay        Normal  Female
# 208  573-58-9734      B   Mandalay        Normal  Female
# 0    750-67-8428      A     Yangon        Member  Female
# 876  885-56-0389      C  Naypyitaw        Member    Male
# 574  550-84-8664      A     Yangon        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 323  563-91-7120      A     Yangon        Normal  Female
# 245  530-90-9855      A     Yangon        Member    Male
# 759  156-95-3964      A     Yangon        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 580      Food and beverages       27.22         3   4.0830   85.7430
# 706  Electronic accessories       43.00         4   8.6000  180.6000
# 208     Fashion accessories       30.37         3   4.5555   95.6655
# ...

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["City"].nunique()
# Out:
# 3

# %%
df["Branch"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Branch"].nunique()
# Out:
# 3

# %%
df.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.Branch.nunique()
# Out:
# 3

# %%
df.Total
# Out:
# 0       548.9715
# 1        80.2200
# 2       340.5255
# 3       489.0480
# 4       634.3785
#          ...
# 995      42.3675
# 996    1022.4900
# 997      33.4320
# 998      69.1110
# 999     649.2990
# Name: Total, Length: 1000, dtype: float64

# %%
df["Total"].max()
# Out:
# 1042.65

# %%
df.Total.max()
# Out:
# 1042.65

# %%
df.Total.max(),df.Total.min(),df["Total"].std(),df["Total"].var(),df.Total.mean(),df.Total.median()
# Out:
# (1042.65,
#  10.6785,
#  245.88533510097207,
#  60459.598017717326,
#  322.96674900000005,
#  253.848)

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#FEATURE ENGİNEERING (öZNİTELİK)

# %%
df["Date"]=pd.to_datetime(df["Date"])#objecti datetime veri tipine çevirdik daha kolay işlem yapabilmek için.

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df["day"]=df["Date"].dt.day#tarihteki gün değerini ayrı bir sütun olarak yazmış olduk.

# %%
df.sample()
# Out:
#       Invoice ID Branch    City Customer type Gender       Product line  \
# 709  445-30-9252      A  Yangon        Normal   Male  Sports and travel
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time  Payment  cogs  \
# 709        25.7         3   3.855  80.955 2019-01-17  17:59  Ewallet  77.1
#
#      gross margin percentage  gross income  Rating  day
# 709                 4.761905         3.855     6.1   17

# %%
df["month"]=df["Date"].dt.month

# %%
df.sample()
# Out:
#       Invoice ID Branch       City Customer type Gender        Product line  \
# 431  574-57-9721      C  Naypyitaw        Normal   Male  Food and beverages
#
#      Unit price  Quantity  Tax 5%   Total       Date   Time  Payment   cogs  \
# 431       43.27         2   4.327  90.867 2019-03-08  16:53  Ewallet  86.54
#
#      gross margin percentage  gross income  Rating  day  month
# 431                 4.761905         4.327     5.7    8      3

# %%
df["year"]=df["Date"].dt.year

# %%
df.sample()
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 735  607-65-2441      C  Naypyitaw        Member   Male  Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 735       81.95        10  40.975  860.475 2019-03-10  12:39  Credit card
#
#       cogs  gross margin percentage  gross income  Rating  day  month  year
# 735  819.5                 4.761905        40.975     6.0   10      3  2019

# %%
df["month_name"]=df["Date"].dt.month_name()

# %%
df.sample()
# Out:
#       Invoice ID Branch       City Customer type Gender       Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male  Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total  ...   Time Payment    cogs  \
# 983       99.96         7  34.986  734.706  ...  10:33    Cash  699.72
#
#      gross margin percentage  gross income  Rating  day  month  year  \
# 983                 4.761905        34.986     6.1   23      1  2019
#
#      month_name
# 983     January
#
# [1 rows x 21 columns]

# %%
df["weekday"]=df["Date"].dt.day_name()

# %%
df.sample()
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 420  266-76-6436      C  Naypyitaw        Member  Female  Food and beverages
#
#      Unit price  Quantity  Tax 5%   Total  ...  Payment   cogs  \
# 420        38.6         3    5.79  121.59  ...  Ewallet  115.8
#
#     gross margin percentage  gross income  Rating  day  month  year  \
# 420                4.761905          5.79     7.5   28      3  2019
#
#      month_name   weekday
# 420       March  Thursday
#
# [1 rows x 22 columns]

# %%
df.Time=pd.to_datetime(df.Time)#object ten datetime a çevirme

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
df["Hour"]=df["Time"].dt.hour

# %%
df.sample()
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 292  278-97-7759      A  Yangon        Member  Female  Electronic accessories
#
#      Unit price  Quantity  Tax 5%   Total  ...   cogs gross margin percentage  \
# 292       62.48         1   3.124  65.604  ...  62.48                4.761905
#
#     gross income  Rating  day  month  year  month_name  weekday  Hour
# 292        3.124     4.7   18      2  2019    February   Monday    20
#
# [1 rows x 23 columns]

# %%
df.Hour.unique().max()
# Out:
# 20

# %%
df.Hour.unique().min()
# Out:
# 10

# %%
plt.figure(figsize=(9.6,6))

# %%
plt.title("MONTHLY TRANSACTION")
# Out:
# Text(0.5, 1.0, 'MONTHLY TRANSACTION')

# %%
sns.countplot(df["month_name"])
plt.xticks(rotation=30);

# %%
plt.figure(figsize=(9.6,6))
sns.countplot(df["Gender"])
plt.title("Male and Female Customers");

# %%
df.Gender.value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df.month_name.value_counts()
# Out:
# January     352
# March       345
# February    303
# Name: month_name, dtype: int64

# %%
df.weekday.value_counts()
# Out:
# Saturday     164
# Tuesday      158
# Wednesday    143
# Friday       139
# Thursday     138
# Sunday       133
# Monday       125
# Name: weekday, dtype: int64

# %%
sns.countplot(df.weekday);

# %%
sns.countplot(df.weekday)
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(8,8))
explode=(0.05,0.01,0.05)
df["month_name"].value_counts().plot.pie(autopct="%1.1f%%",startangle=60,explode=explode)
plt.title("TRANSACTION PER MOUNTH");

# %%
plt.figure(figsize=(8,8))
explode=(0.05,0.01,0.05)
df["Product line"].value_counts().plot.pie(autopct="%1.1f%%",startangle=60)
plt.title("TRANSACTION PER MOUNTH");

# %%
sns.countplot(df["Product line"]);

# %%
sns.countplot(df["Product line"])
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6))
sns.countplot(df["Product line"])
plt.title("TRANSACTION PER MOUNTH");

# %%
plt.figure(figsize=(12,6))
plt.title("TRANSACTION PER MOUNTH")
sns.countplot(df["Product line"],hue=df.Gender)
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(12,8))
plt.title("TRANSACTION PER MOUNTH")
sns.countplot(df.Branch,hue=df["Product line"]);

# %%
plt.figure(figsize=(12,8))
plt.title("TRANSACTION PER MOUNTH")
sns.countplot(df["Product line"],hue=df.Branch);

# %%
plt.title("Count plot of Customers")
sns.countplot(df["Customer type"])
# Out:
# <AxesSubplot:title={'center':'Count plot of Customers'}, xlabel='Customer type', ylabel='count'>

# %%
plt.title("TOTAL MOUNTHLY TRANSACTION")
sns.countplot(df.City,hue=df.Branch);

# %%
sns.barplot(x=df.City,y=df.index,palette="hot")
# Out:
# <AxesSubplot:xlabel='City'>

# %%
plt.title("CITY OF GENDER")
sns.countplot(df.City,hue=df.Gender);

# %%
sns.barplot(x=df.Payment,y=df.index);

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df["Product line"],y=df["gross income"]);

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df["Product line"],y=df["gross income"])
plt.xticks(rotation=45);
